# %%
#example [N, S] https://michaelnielsen.org/ddi/if-correlation-doesnt-imply-causation-then-what-does/
D=[77/80, 3/20]
R=[84/90,1/10]
T=[80/100,85/100]
print(D, R, T)
# Out:
# [0.9625, 0.15] [0.9333333333333333, 0.1] [0.8, 0.85]

# %%
# !wget https://raw.githubusercontent.com/animesh/SimpsonsParadox/master/simpsons_paradox.py
# !wget https://raw.githubusercontent.com/animesh/SimpsonsParadox/master/utilities.py
# Out:
# --2023-10-10 13:20:56--  https://raw.githubusercontent.com/animesh/SimpsonsParadox/master/simpsons_paradox.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23783 (23K) [text/plain]
# Saving to: ‘simpsons_paradox.py.1’
#
# simpsons_paradox.py 100%[===================>]  23.23K  --.-KB/s    in 0.002s
#
# 2023-10-10 13:20:56 (10.2 MB/s) - ‘simpsons_paradox.py.1’ saved [23783/23783]
#
# --2023-10-10 13:20:56--  https://raw.githubusercontent.com/animesh/SimpsonsParadox/master/utilities.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1113 (1.1K) [text/plain]
# Saving to: ‘utilities.py’
#
# utilities.py        100%[===================>]   1.09K  --.-KB/s    in 0s
#
# 2023-10-10 13:20:56 (57.8 MB/s) - ‘utilities.py’ saved [1113/1113]

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from simpsons_paradox import SimpsonsParadox

# %%
plt.rcParams["figure.figsize"] = (10, 7)
sns.set(style="darkgrid")
sns.set(font_scale=1.5)

# %% [markdown]
# ### Load Data

# %%
## Example 1: Disease Data
disease = pd.read_csv('https://raw.githubusercontent.com/animesh/SimpsonsParadox/master/data/SP_Data.txt')

## Example 2: Census Data
## Needs weighting=False to display weak Simpson's pair
# df = pd.read_csv('data/CensusModified.csv')
# dv = 'Income'
# bin_columns = []
# ignore_columns = []

## Example 3: Baseball Data
## Needs max_pvalue=1
# df = pd.read_csv('data/baseball_data.csv')
# dv = 'outcome'
# bin_columns = []
# ignore_columns = ['Unnamed: 0']

## Example 4: Admissions Data
# df = pd.read_csv('data/admissions_data.csv')
# dv = 'Admit'
# bin_columns = []
# ignore_columns = ['Unnamed: 0']

## Example 5: Khan Academy Data
# df = pd.read_csv('data/small_khancademy.csv')
# dv = 'performance'
# bin_columns = ['timestamp', 'solve_time', 'attempts',
#                'tspp', 'session_num', 'session_index',
#               'session_length', 'all_first_attempts',
#                'signup_duration', 'total_solving_time',
#               'all_attempts', 'all_problems',
#                'all_sequences', 'month', 'join_month']
# ignore_columns = ["user_id", "problem_id"]

## Example 6: Coffee Data
# df = pd.read_csv('data/coffee_data.csv')
# dv = 'neuroticism'
# bin_columns = []
# ignore_columns = ['Unnamed: 0']

## Example 7: Student Performance Data
# df = pd.read_csv('data/student-mat.csv', sep=";")
# df['final_grade'] = np.where(df['G3'] >= 10, 1, 0)
# dv = 'final_grade'
# bin_columns = []
# ignore_columns = []

## Example 8: T.A. Evaluation Data
# df = pd.read_csv('data/TeachingAssistant_EvaluationDataset.csv')
# dv = 'Score'
# bin_columns = []
# ignore_columns = []

## Example 9: Breast Cancer Data
# df = pd.read_csv("data/breastcancer_data.csv")
# dv = "class"
# bin_columns = []
# ignore_columns = []

## Example 10: Iris Flower Data
from sklearn.datasets import load_iris
iris = load_iris(as_frame=True).frame

# %% [markdown]
# ### Get Simpson's Pairs

# %%
sp_iris = SimpsonsParadox(df=iris, dv='target', target_category=1, output_plots=True, quiet=True)
sp_iris.get_simpsons_pairs()
# Out:
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# Independent Variable: sepal width (cm)
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
#                   variable  coefficient        pvalue      -95%     odds  \
# 1  sepal width (cm)_scaled    -1.399825  4.254283e-07  0.143368  0.24664
#
#        +95%
# 1  0.424301
# Conditioned on: petal length (cm)
#    bin_size variable  coefficient    pvalue      -95%           odds  \
# 1        34  bin 1.0  -291.255037       NaN       NaN  3.232545e-127
# 1        30  bin 3.0     1.042365  0.164042  0.653298   2.835915e+00
# 1        32  bin 2.0     1.514245  0.351890  0.187529   4.545990e+00
#
#          +95%
# 1         NaN
# 1   12.310479
# 1  110.201762
# Independent Variable: sepal width (cm)
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
#                   variable  coefficient        pvalue      -95%     odds  \
# 1  sepal width (cm)_scaled    -1.399825  4.254283e-07  0.143368  0.24664
#
#        +95%
# 1  0.424301
# Conditioned on: petal width (cm)
#   variable  coefficient    pvalue      -95%      odds        +95%  bin_size
# 1  bin 1.0    -3.733215  0.002932  0.002044  0.023916    0.279830        55
# 1  bin 2.0     1.642502  0.381750  0.130289  5.168084  204.998723        26
# 1  bin 3.0     0.669444  0.263341  0.604350  1.953150    6.312224        30
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# Independent Variable: petal length (cm)
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
#                    variable  coefficient   pvalue      -95%      odds  \
# 1  petal length (cm)_scaled     0.449868  0.01502  1.091224  1.568105
#
#        +95%
# 1  2.253391
# Conditioned on: petal width (cm)
#   variable  coefficient    pvalue          -95%          odds      +95%  \
# 1  bin 1.0   109.573628  0.999958  0.000000e+00  3.865646e+47       inf
# 1  bin 2.0   -81.996634  0.990821  0.000000e+00  2.450835e-36       inf
# 1  bin 3.0    -9.307847  0.011878  6.432266e-08  9.070966e-05  0.127921
#
#    bin_size
# 1        55
# 1        26
# 1        30
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# [('sepal width (cm)', 'petal length (cm)'),
#  ('sepal width (cm)', 'petal width (cm)'),
#  ('petal length (cm)', 'petal width (cm)')]

# %%
sp_disease = SimpsonsParadox(df=disease, dv='Survived', ignore_columns=['PatientId'], output_plots=True)
sp_disease.get_simpsons_pairs()
# Out:
# ===============================================================================
# Warning! Simpson’s Paradox was detected in this pair of variables:
# ('Treated', 'Gender')
# ===============================================================================
# Independent Variable: Treated
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
#   variable  coefficient    pvalue      -95%      odds      +95%
# 1  Treated     0.537143  0.000172  1.292881  1.711112  2.264635
# Conditioned on: Gender
#   variable  coefficient    pvalue      -95%      odds      +95%  bin_size
# 1    bin 1    -0.348296  0.189493  0.419549  0.705890  1.187657       400
# 1    bin 0    -0.636022  0.035764  0.292367  0.529394  0.958583       500
# 1 Simpson’s Pair(s) were detected in your dataset.
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# /content/simpsons_paradox.py:328: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reg_table = reg_table.append(model_df)
# [('Treated', 'Gender')]
